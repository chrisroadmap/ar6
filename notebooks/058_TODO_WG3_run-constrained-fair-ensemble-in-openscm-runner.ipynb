# %%
import os.path

import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyam
from fair.forward import fair_scm
from scmdata import ScmRun, run_append
from tqdm import tqdm_notebook

import openscm_runner
from openscm_runner.run import run
from openscm_runner.adapters import FAIR
# Out:
# /nfs/b0110/Users/mencsm/miniconda3/envs/ar6-fair/lib/python3.7/site-packages/openscm_runner/run.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
openscm_runner.__version__
# Out:
# '0.4.4'

# %%
fair = FAIR()
fair.get_version()
# Out:
# '1.6.1'

# %%
with open('../data/fair_testing.json') as f:
    config_list = json.load(f)

# %%
# what a pain

species = [
'Emissions|BC',
'Emissions|CH4',
'Emissions|CO',
'Emissions|CO2|MAGICC AFOLU',
'Emissions|CO2|MAGICC Fossil and Industrial',
'Emissions|F-Gases|HFC|HFC125',
'Emissions|F-Gases|HFC|HFC134a',
'Emissions|F-Gases|HFC|HFC143a',
'Emissions|F-Gases|HFC|HFC227ea',
'Emissions|F-Gases|HFC|HFC23',
'Emissions|F-Gases|HFC|HFC245fa',
'Emissions|F-Gases|HFC|HFC32',
'Emissions|F-Gases|HFC|HFC4310mee',
'Emissions|F-Gases|PFC|C2F6',
'Emissions|F-Gases|PFC|C6F14',
'Emissions|F-Gases|PFC|CF4',
'Emissions|F-Gases|SF6',
'Emissions|Montreal Gases|CCl4',
'Emissions|Montreal Gases|CFC|CFC11',
'Emissions|Montreal Gases|CFC|CFC113',
'Emissions|Montreal Gases|CFC|CFC114',
'Emissions|Montreal Gases|CFC|CFC115',
'Emissions|Montreal Gases|CFC|CFC12',
'Emissions|Montreal Gases|CH3Br',
'Emissions|Montreal Gases|CH3CCl3',
'Emissions|Montreal Gases|CH3Cl',
'Emissions|Montreal Gases|HCFC141b',
'Emissions|Montreal Gases|HCFC142b',
'Emissions|Montreal Gases|HCFC22',
'Emissions|Montreal Gases|Halon1202',
'Emissions|Montreal Gases|Halon1211',
'Emissions|Montreal Gases|Halon1301',
'Emissions|Montreal Gases|Halon2402',
'Emissions|N2O',
'Emissions|NH3',
'Emissions|NOx',
'Emissions|OC',
'Emissions|Sulfur',
'Emissions|VOC']

# %%
df_fair = ScmRun('../data/rcmip-emissions-annual-means-v5-1-0.csv', lowercase_cols=True)
df_fair.filter(
    scenario=['ssp119','ssp126','ssp245','ssp370','ssp434','ssp460','ssp534-over','ssp585'], 
#    scenario=['ssp245'],
    year=range(2015,2301),
    variable=species,
    region='World', 
    inplace=True
)
print(len(df_fair))
#df_fair.head(50)
# Out:
# 312

# %%
nt = df_fair.time_points.years()[-1] - 1750 + 1
nt
# Out:
# 551

# %%
# # add in natural emissions and natural forcing
# ch4_n2o_df = pd.read_csv('../data/cmip6_natural_ch4_n2o.csv')
# ch4_n2o = ch4_n2o_df.values[:nt,1:]
# sol_vol_df = pd.read_csv('../data/cmip6_natural_forcing.csv')
# solar_forcing = sol_vol_df.values[:nt,1]
# volcanic_forcing = sol_vol_df.values[:nt,2]

# %%
#config_list[0]

# %%
# convert lists to numpy arrays
updated_config = []
for i in range(len(config_list)):
    updated_config.append({})
    for key, value in config_list[i].items():
        if type(value)==list:
            updated_config[i][key] = np.asarray(value)
        else:
            updated_config[i][key] = value
#     updated_config[i]['endyear'] = 2300
#     updated_config[i]['natural'] = ch4_n2o
#     updated_config[i]['F_solar'] = solar_forcing
#     updated_config[i]['F_volcanic'] = volcanic_forcing

# %%
x = run(
    climate_models_cfgs={
        "FAIR": updated_config,
    },
    scenarios=df_fair,
    output_variables=(
        "Surface Temperature",
        "Surface Temperature (GMST)",
        "Atmospheric Concentrations|CO2",
        "Atmospheric Concentrations|CH4",
        "Atmospheric Concentrations|N2O",
        "Effective Radiative Forcing",
        "Effective Radiative Forcing|CO2",
        "Effective Radiative Forcing|CH4",
        "Effective Radiative Forcing|N2O",
        "Effective Radiative Forcing|Greenhouse Gases",
        "Effective Radiative Forcing|Aerosols",
        "Effective Radiative Forcing|Aerosols|Direct Effect|BC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|OC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|Sulfur",
        "Effective Radiative Forcing|Aerosols|Direct Effect|Nitrate",
        "Effective Radiative Forcing|Aerosols|Direct Effect",
        "Effective Radiative Forcing|Aerosols|Indirect Effect",
        "Heat Uptake",
        "Heat Uptake|Ocean",
        "Airborne Fraction",
    ),
)
# Out:
# Climate models:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating FaIR emissions inputs:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# convert to ScmRun for better plotting functionality
x = ScmRun(x.timeseries())

# %%
x.tail()
# Out:
# time                                                                                                                 1750-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect         7.171194e-10
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         1.494198e-09
#                                                    J/yr          Heat Uptake                                                3.776468e+21
#                                                                  Heat Uptake|Ocean                                          3.474351e+21
#                                                    dimensionless Airborne Fraction                                          0.000000e+00
#
# time                                                                                                                 1751-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect         1.825202e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         9.393880e-03
#                                                    J/yr          Heat Uptake                                                3.241795e+21
#                                                                  Heat Uptake|Ocean                                          2.982452e+21
#                                                    dimensionless Airborne Fraction                                          7.674220e-01
#
# time                                                                                                                 1752-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect         3.116902e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         1.476528e-02
#                                                    J/yr          Heat Uptake                                                2.640295e+21
#                                                                  Heat Uptake|Ocean                                          2.429071e+21
#                                                    dimensionless Airborne Fraction                                          7.029387e-01
#
# time                                                                                                                 1753-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect         1.796949e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         9.621791e-03
#                                                    J/yr          Heat Uptake                                                1.919026e+21
#                                                                  Heat Uptake|Ocean                                          1.765504e+21
#                                                    dimensionless Airborne Fraction                                          6.662115e-01
#
# time                                                                                                                 1754-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.296286e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...        -3.756197e-03
#                                                    J/yr          Heat Uptake                                                1.115463e+21
#                                                                  Heat Uptake|Ocean                                          1.026226e+21
#                                                    dimensionless Airborne Fraction                                          6.393137e-01
#
# time                                                                                                                 1755-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect         8.883025e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         2.881857e-03
#                                                    J/yr          Heat Uptake                                                4.514941e+20
#                                                                  Heat Uptake|Ocean                                          4.153746e+20
#                                                    dimensionless Airborne Fraction                                          6.176834e-01
#
# time                                                                                                                 1756-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect         1.426542e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         9.263826e-03
#                                                    J/yr          Heat Uptake                                               -1.407882e+21
#                                                                  Heat Uptake|Ocean                                         -1.295251e+21
#                                                    dimensionless Airborne Fraction                                          5.993355e-01
#
# time                                                                                                                 1757-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.088246e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...        -1.026416e-02
#                                                    J/yr          Heat Uptake                                               -1.759948e+21
#                                                                  Heat Uptake|Ocean                                         -1.619153e+21
#                                                    dimensionless Airborne Fraction                                          5.836702e-01
#
# time                                                                                                                 1758-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -8.177636e-05
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...        -3.054495e-03
#                                                    J/yr          Heat Uptake                                                4.619552e+20
#                                                                  Heat Uptake|Ocean                                          4.249988e+20
#                                                    dimensionless Airborne Fraction                                          5.698766e-01
#
# time                                                                                                                 1759-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -8.425265e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...        -4.875354e-03
#                                                    J/yr          Heat Uptake                                                2.018098e+21
#                                                                  Heat Uptake|Ocean                                          1.856650e+21
#                                                    dimensionless Airborne Fraction                                          5.577587e-01
#
# time                                                                                                                 ...  \
# climate_model model         region run_id scenario unit          variable                                            ...
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  ...
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  ...
#                                                    J/yr          Heat Uptake                                         ...
#                                                                  Heat Uptake|Ocean                                   ...
#                                                    dimensionless Airborne Fraction                                   ...
#
# time                                                                                                                 2291-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.777158e+22
#                                                                  Heat Uptake|Ocean                                          4.394985e+22
#                                                    dimensionless Airborne Fraction                                          6.995986e-01
#
# time                                                                                                                 2292-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.736716e+22
#                                                                  Heat Uptake|Ocean                                          4.357778e+22
#                                                    dimensionless Airborne Fraction                                          6.991394e-01
#
# time                                                                                                                 2293-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.705743e+22
#                                                                  Heat Uptake|Ocean                                          4.329284e+22
#                                                    dimensionless Airborne Fraction                                          6.986819e-01
#
# time                                                                                                                 2294-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.692326e+22
#                                                                  Heat Uptake|Ocean                                          4.316940e+22
#                                                    dimensionless Airborne Fraction                                          6.982259e-01
#
# time                                                                                                                 2295-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.703876e+22
#                                                                  Heat Uptake|Ocean                                          4.327566e+22
#                                                    dimensionless Airborne Fraction                                          6.977716e-01
#
# time                                                                                                                 2296-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.723529e+22
#                                                                  Heat Uptake|Ocean                                          4.345647e+22
#                                                    dimensionless Airborne Fraction                                          6.973189e-01
#
# time                                                                                                                 2297-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.737881e+22
#                                                                  Heat Uptake|Ocean                                          4.358850e+22
#                                                    dimensionless Airborne Fraction                                          6.968678e-01
#
# time                                                                                                                 2298-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.731344e+22
#                                                                  Heat Uptake|Ocean                                          4.352837e+22
#                                                    dimensionless Airborne Fraction                                          6.964182e-01
#
# time                                                                                                                 2299-01-01 00:00:00  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.691169e+22
#                                                                  Heat Uptake|Ocean                                          4.315876e+22
#                                                    dimensionless Airborne Fraction                                          6.959703e-01
#
# time                                                                                                                 2300-01-01 00:00:00
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.1    REMIND-MAGPIE World  6799   ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect        -1.059201e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...         4.840928e-02
#                                                    J/yr          Heat Uptake                                                4.653365e+22
#                                                                  Heat Uptake|Ocean                                          4.281095e+22
#                                                    dimensionless Airborne Fraction                                          6.955240e-01
#
# [5 rows x 551 columns]

# %%
def new_timeseries(
    n=100,
    count=1,
    model="example",
    scenario="ssp119",
    variable="Surface Temperature",
    unit="K",
    region="World",
    cls=ScmRun,
    **kwargs,
):
    data = np.random.rand(n, count) * np.arange(n)[:, np.newaxis]
    index = 2000 + np.arange(n)
    return cls(
        data,
        columns={
            "model": model,
            "scenario": scenario,
            "variable": variable,
            "region": region,
            "unit": unit,
            **kwargs,
        },
        index=index,
    )

# %%
# save output to netCDF
x.to_nc('../output/emissions_driven_runs.nc', dimensions=["run_id", "scenario", "model"])

# %%
x = ScmRun.from_nc('../output/emissions_driven_runs.nc')

from scmdata.plotting import RCMIP_SCENARIO_COLOURS

# %%
plt.rcParams['font.size'] = 14
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
# x.filter(variable="Surface Temperature").relative_to_ref_period_mean(year=range(1985,2005)).lineplot(
#     hue="scenario", style="model", ax=ax, time_axis="year", palette=RCMIP_SCENARIO_COLOURS,
#     hue_order=RCMIP_SCENARIO_COLOURS.keys(),
# )
x.filter(variable="Surface Temperature").relative_to_ref_period_mean(year=range(1850,1900)).lineplot(
    hue="scenario",
    ax=ax,
    time_axis="year",
    palette=RCMIP_SCENARIO_COLOURS,
    hue_order=RCMIP_SCENARIO_COLOURS.keys(),
)
ax.set_xlim(1850,2300)
#ax.axhline(0, color='k', ls=':')
ax.grid()
ax.set_title('SSP projections with FaIR: 1850-2300')
plt.tight_layout()
plt.savefig('../plots/temp_ssp_proj_ssps.png')

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|BC").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|OC").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|Sulfur").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|Nitrate").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Indirect Effect").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|CO2").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|CH4").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|N2O").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Heat Uptake").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Airborne Fraction").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
x.filter(scenario='ssp119', variable="Atmospheric Concentrations|CO2").timeseries()
# Out:
# time                                                                            1750-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.202674
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.721394
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.738587
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.837605
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.735729
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           276.920765
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           276.896742
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.303004
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           277.869682
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.246479
#
# time                                                                            1751-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.215380
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.733193
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.751819
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.849377
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.747916
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           276.932509
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           276.908493
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.316452
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           277.882476
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.257265
#
# time                                                                            1752-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.240780
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.757198
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.778043
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.873349
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.772497
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           276.956426
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           276.932457
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.343021
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           277.908028
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.279811
#
# time                                                                            1753-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.265971
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.781460
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.803796
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.897604
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.797124
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           276.980626
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           276.956744
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.369008
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           277.933358
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.303180
#
# time                                                                            1754-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.290750
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.805332
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.829114
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.921472
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.821362
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           277.004433
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           276.980659
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.394534
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           277.958299
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.326107
#
# time                                                                            1755-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.315115
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.828744
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.854054
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.944877
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.845169
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           277.027775
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           277.004115
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.419690
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           277.982850
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.348492
#
# time                                                                            1756-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.339122
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.851760
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.878680
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.967878
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.868603
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           277.050720
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           277.027166
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.444549
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           278.007057
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.370424
#
# time                                                                            1757-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.362846
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.874497
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.903084
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           277.990586
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.891778
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           277.073389
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           277.049900
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.469207
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           278.030991
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.392029
#
# time                                                                            1758-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.386345
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.897031
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.927315
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           278.013069
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.914763
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           277.095862
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           277.072372
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.493712
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           278.054689
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.413392
#
# time                                                                            1759-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           277.409724
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           274.919404
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           276.951410
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           278.035390
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           280.937592
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           277.118175
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           277.094673
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           279.518093
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           278.078232
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           277.434596
#
# time                                                                            ...  \
# climate_model model region run_id scenario unit variable                        ...
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  ...
# ...                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2  ...
#
# time                                                                            2291-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.634060
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.474300
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.369963
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           334.015306
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.788432
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.294069
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.674631
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.309375
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.490042
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.375797
#
# time                                                                            2292-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.616615
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.450596
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.350964
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.989467
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.767116
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.268224
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.646632
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.297202
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.467980
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.344281
#
# time                                                                            2293-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.599230
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.426986
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.332042
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.963726
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.745895
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.242479
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.618684
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.285094
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.445983
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.312808
#
# time                                                                            2294-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.581908
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.403470
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.313195
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.938082
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.724770
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.216834
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.590782
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.273050
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.424044
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.281376
#
# time                                                                            2295-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.564651
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.380050
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.294422
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.912536
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.703742
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.191289
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.562927
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.261071
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.402164
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.249988
#
# time                                                                            2296-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.547473
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.356728
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.275729
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.887095
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.682811
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.165848
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.535134
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.249157
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.380357
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.218657
#
# time                                                                            2297-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.530385
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.333507
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.257123
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.861769
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.661980
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.140509
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.507426
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.237313
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.358640
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.187403
#
# time                                                                            2298-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.513395
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.310389
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.238614
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.836564
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.641248
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.115275
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.479825
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.225539
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.337033
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.156242
#
# time                                                                            2299-01-01 00:00:00  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.496506
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.287377
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.220205
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.811485
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.620618
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.090147
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.452344
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.213837
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.315548
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.125184
#
# time                                                                            2300-01-01 00:00:00
# climate_model model region run_id scenario unit variable
# FaIRv1.6.1    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2           331.479707
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2           330.264470
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2           331.201894
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2           333.786529
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2           335.600089
# ...                                                                                             ...
#                            845    ssp119   ppm  Atmospheric Concentrations|CO2           333.065124
#                            846    ssp119   ppm  Atmospheric Concentrations|CO2           334.424982
#                            847    ssp119   ppm  Atmospheric Concentrations|CO2           332.202206
#                            848    ssp119   ppm  Atmospheric Concentrations|CO2           333.294179
#                            849    ssp119   ppm  Atmospheric Concentrations|CO2           336.094225
#
# [850 rows x 551 columns]

# %%
x.filter(variable="Atmospheric Concentrations|N2O", scenario='ssp119', run_id=0).timeseries().values.squeeze()[264]
# Out:
# 326.97706688972875

# %%
x.filter(variable="Atmospheric Concentrations|CH4", scenario='ssp119', run_id=0).timeseries().values.squeeze()[264]
# Out:
# 1831.4709981026217
