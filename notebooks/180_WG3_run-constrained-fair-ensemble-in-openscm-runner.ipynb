# %% [markdown]
# # Apply the constrained setup and run in openscm-runner
#
# - Working Group 3 style setup
# - TODO: parallel

# %%
import os.path

import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyam
from fair.forward import fair_scm
from scmdata import ScmRun, run_append
from tqdm import tqdm_notebook

import openscm_runner
from openscm_runner.run import run
from openscm_runner.adapters import FAIR
# Out:
# /nfs/b0110/Users/mencsm/miniconda3/envs/ar6/lib/python3.7/site-packages/openscm_runner/run.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
openscm_runner.__version__
# Out:
# '0.4.4'

# %%
fair = FAIR()
fair.get_version()
# Out:
# '1.6.2'

# %%
with open('../data_output_large/fair-samples/fair-1.6.2-wg3-params.json') as f:
    config_list = json.load(f)

# %%
# what a pain

species = [
'Emissions|BC',
'Emissions|CH4',
'Emissions|CO',
'Emissions|CO2|MAGICC AFOLU',
'Emissions|CO2|MAGICC Fossil and Industrial',
'Emissions|F-Gases|HFC|HFC125',
'Emissions|F-Gases|HFC|HFC134a',
'Emissions|F-Gases|HFC|HFC143a',
'Emissions|F-Gases|HFC|HFC227ea',
'Emissions|F-Gases|HFC|HFC23',
'Emissions|F-Gases|HFC|HFC245fa',
'Emissions|F-Gases|HFC|HFC32',
'Emissions|F-Gases|HFC|HFC4310mee',
'Emissions|F-Gases|PFC|C2F6',
'Emissions|F-Gases|PFC|C6F14',
'Emissions|F-Gases|PFC|CF4',
'Emissions|F-Gases|SF6',
'Emissions|Montreal Gases|CCl4',
'Emissions|Montreal Gases|CFC|CFC11',
'Emissions|Montreal Gases|CFC|CFC113',
'Emissions|Montreal Gases|CFC|CFC114',
'Emissions|Montreal Gases|CFC|CFC115',
'Emissions|Montreal Gases|CFC|CFC12',
'Emissions|Montreal Gases|CH3Br',
'Emissions|Montreal Gases|CH3CCl3',
'Emissions|Montreal Gases|CH3Cl',
'Emissions|Montreal Gases|HCFC141b',
'Emissions|Montreal Gases|HCFC142b',
'Emissions|Montreal Gases|HCFC22',
'Emissions|Montreal Gases|Halon1202',
'Emissions|Montreal Gases|Halon1211',
'Emissions|Montreal Gases|Halon1301',
'Emissions|Montreal Gases|Halon2402',
'Emissions|N2O',
'Emissions|NH3',
'Emissions|NOx',
'Emissions|OC',
'Emissions|Sulfur',
'Emissions|VOC']

# %%
df_fair = ScmRun('../data_input_large/rcmip-emissions-annual-means-v5-1-0.csv', lowercase_cols=True)
df_fair.filter(
    scenario=['ssp119','ssp126','ssp245','ssp370','ssp434','ssp460','ssp534-over','ssp585'], 
#    year=range(2015,2301),
    year=range(2015,2101),
    variable=species,
    region='World', 
    inplace=True
)
print(len(df_fair))
#df_fair.head(50)
# Out:
# 312

# %%
nt = df_fair.time_points.years()[-1] - 1750 + 1
nt
# Out:
# 351

# %%
# # add in natural emissions and natural forcing
# ch4_n2o_df = pd.read_csv('../data/cmip6_natural_ch4_n2o.csv')
# ch4_n2o = ch4_n2o_df.values[:nt,1:]
# sol_vol_df = pd.read_csv('../data/cmip6_natural_forcing.csv')
# solar_forcing = sol_vol_df.values[:nt,1]
# volcanic_forcing = sol_vol_df.values[:nt,2]

# %%
#config_list[0]

# %%
# convert lists to numpy arrays
updated_config = []
for i in range(len(config_list)):
    updated_config.append({})
    for key, value in config_list[i].items():
        if type(value)==list:
            updated_config[i][key] = np.asarray(value)
        else:
            updated_config[i][key] = value
#     updated_config[i]['endyear'] = 2300
#     updated_config[i]['natural'] = ch4_n2o
#     updated_config[i]['F_solar'] = solar_forcing
#     updated_config[i]['F_volcanic'] = volcanic_forcing

# %%
# need parallel FaIR in openscm-runner

x = run(
    climate_models_cfgs={
        "FAIR": updated_config,
    },
    scenarios=df_fair,
    output_variables=(
        "Surface Temperature",
        "Surface Temperature (GMST)",
        "Atmospheric Concentrations|CO2",
        "Atmospheric Concentrations|CH4",
        "Atmospheric Concentrations|N2O",
        "Effective Radiative Forcing",
        "Effective Radiative Forcing|CO2",
        "Effective Radiative Forcing|CH4",
        "Effective Radiative Forcing|N2O",
        "Effective Radiative Forcing|Greenhouse Gases",
        "Effective Radiative Forcing|Aerosols",
        "Effective Radiative Forcing|Aerosols|Direct Effect|BC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|OC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|Sulfur",
        "Effective Radiative Forcing|Aerosols|Direct Effect|Nitrate",
        "Effective Radiative Forcing|Aerosols|Direct Effect",
        "Effective Radiative Forcing|Aerosols|Indirect Effect",
        "Heat Uptake",
        "Heat Uptake|Ocean",
        "Airborne Fraction",
    ),
)
# Out:
# Climate models:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating FaIR emissions inputs:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# convert to ScmRun for better plotting functionality
x = ScmRun(x.timeseries())

# %%
x.tail()
# Out:
# time                                                                                                                   1750-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  5.735094e-10
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  5.432287e-10
#                                                    J/yr          Heat Uptake                                         3.512394e+21
#                                                                  Heat Uptake|Ocean                                   3.231403e+21
#                                                    dimensionless Airborne Fraction                                   0.000000e+00
#
# time                                                                                                                   1751-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -6.286588e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  3.442245e-03
#                                                    J/yr          Heat Uptake                                         2.385162e+21
#                                                                  Heat Uptake|Ocean                                   2.194349e+21
#                                                    dimensionless Airborne Fraction                                   7.742945e-01
#
# time                                                                                                                   1752-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -5.681946e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  5.300065e-03
#                                                    J/yr          Heat Uptake                                         1.538229e+21
#                                                                  Heat Uptake|Ocean                                   1.415171e+21
#                                                    dimensionless Airborne Fraction                                   7.093568e-01
#
# time                                                                                                                   1753-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -7.259608e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  3.470978e-03
#                                                    J/yr          Heat Uptake                                         9.786318e+20
#                                                                  Heat Uptake|Ocean                                   9.003413e+20
#                                                    dimensionless Airborne Fraction                                   6.724056e-01
#
# time                                                                                                                   1754-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -5.424099e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.534047e-03
#                                                    J/yr          Heat Uptake                                         5.692478e+20
#                                                                  Heat Uptake|Ocean                                   5.237080e+20
#                                                    dimensionless Airborne Fraction                                   6.454498e-01
#
# time                                                                                                                   1755-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  4.041129e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  8.393595e-04
#                                                    J/yr          Heat Uptake                                         1.988920e+20
#                                                                  Heat Uptake|Ocean                                   1.829807e+20
#                                                    dimensionless Airborne Fraction                                   6.238190e-01
#
# time                                                                                                                   1756-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.107366e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  3.209096e-03
#                                                    J/yr          Heat Uptake                                        -1.595292e+21
#                                                                  Heat Uptake|Ocean                                  -1.467668e+21
#                                                    dimensionless Airborne Fraction                                   6.054823e-01
#
# time                                                                                                                   1757-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  2.295884e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -4.306380e-03
#                                                    J/yr          Heat Uptake                                        -1.431723e+21
#                                                                  Heat Uptake|Ocean                                  -1.317186e+21
#                                                    dimensionless Airborne Fraction                                   5.898142e-01
#
# time                                                                                                                   1758-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  1.181989e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.633116e-03
#                                                    J/yr          Heat Uptake                                         8.623789e+20
#                                                                  Heat Uptake|Ocean                                   7.933886e+20
#                                                    dimensionless Airborne Fraction                                   5.760377e-01
#
# time                                                                                                                   1759-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  6.312290e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -2.076609e-03
#                                                    J/yr          Heat Uptake                                         1.893459e+21
#                                                                  Heat Uptake|Ocean                                   1.741983e+21
#                                                    dimensionless Airborne Fraction                                   5.639461e-01
#
# time                                                                                                                 ...  \
# climate_model model         region run_id scenario unit          variable                                            ...
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  ...
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  ...
#                                                    J/yr          Heat Uptake                                         ...
#                                                                  Heat Uptake|Ocean                                   ...
#                                                    dimensionless Airborne Fraction                                   ...
#
# time                                                                                                                   2091-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.174893e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -4.371417e-01
#                                                    J/yr          Heat Uptake                                         3.288356e+22
#                                                                  Heat Uptake|Ocean                                   3.025288e+22
#                                                    dimensionless Airborne Fraction                                   6.393152e-01
#
# time                                                                                                                   2092-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.208226e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -4.281155e-01
#                                                    J/yr          Heat Uptake                                         3.316090e+22
#                                                                  Heat Uptake|Ocean                                   3.050803e+22
#                                                    dimensionless Airborne Fraction                                   6.415754e-01
#
# time                                                                                                                   2093-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.241650e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -4.188695e-01
#                                                    J/yr          Heat Uptake                                         3.324561e+22
#                                                                  Heat Uptake|Ocean                                   3.058596e+22
#                                                    dimensionless Airborne Fraction                                   6.437784e-01
#
# time                                                                                                                   2094-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.274983e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -4.094457e-01
#                                                    J/yr          Heat Uptake                                         3.312581e+22
#                                                                  Heat Uptake|Ocean                                   3.047574e+22
#                                                    dimensionless Airborne Fraction                                   6.459270e-01
#
# time                                                                                                                   2095-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.308316e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.998099e-01
#                                                    J/yr          Heat Uptake                                         3.305226e+22
#                                                                  Heat Uptake|Ocean                                   3.040808e+22
#                                                    dimensionless Airborne Fraction                                   6.480233e-01
#
# time                                                                                                                   2096-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.341649e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.899524e-01
#                                                    J/yr          Heat Uptake                                         3.303357e+22
#                                                                  Heat Uptake|Ocean                                   3.039088e+22
#                                                    dimensionless Airborne Fraction                                   6.500695e-01
#
# time                                                                                                                   2097-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.375073e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.798347e-01
#                                                    J/yr          Heat Uptake                                         3.309666e+22
#                                                                  Heat Uptake|Ocean                                   3.044893e+22
#                                                    dimensionless Airborne Fraction                                   6.520680e-01
#
# time                                                                                                                   2098-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.408406e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.695010e-01
#                                                    J/yr          Heat Uptake                                         3.322206e+22
#                                                                  Heat Uptake|Ocean                                   3.056429e+22
#                                                    dimensionless Airborne Fraction                                   6.540212e-01
#
# time                                                                                                                   2099-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.441739e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.589118e-01
#                                                    J/yr          Heat Uptake                                         3.341197e+22
#                                                                  Heat Uptake|Ocean                                   3.073901e+22
#                                                    dimensionless Airborne Fraction                                   6.559317e-01
#
# time                                                                                                                   2100-01-01
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  16391  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.475071e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.480543e-01
#                                                    J/yr          Heat Uptake                                         3.370264e+22
#                                                                  Heat Uptake|Ocean                                   3.100643e+22
#                                                    dimensionless Airborne Fraction                                   6.578021e-01
#
# [5 rows x 351 columns]

# %%
def new_timeseries(
    n=100,
    count=1,
    model="example",
    scenario="ssp119",
    variable="Surface Temperature",
    unit="K",
    region="World",
    cls=ScmRun,
    **kwargs,
):
    data = np.random.rand(n, count) * np.arange(n)[:, np.newaxis]
    index = 2000 + np.arange(n)
    return cls(
        data,
        columns={
            "model": model,
            "scenario": scenario,
            "variable": variable,
            "region": region,
            "unit": unit,
            **kwargs,
        },
        index=index,
    )

# %%
# save output to netCDF
x.to_nc('../data_output_large/fair-samples/ssp_emissions_driven_runs.nc', dimensions=["run_id", "scenario", "model"])

# %%
x = ScmRun.from_nc('../data_output_large/fair-samples/ssp_emissions_driven_runs.nc')

from scmdata.plotting import RCMIP_SCENARIO_COLOURS

# %%
plt.rcParams['font.size'] = 14
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
# x.filter(variable="Surface Temperature").relative_to_ref_period_mean(year=range(1985,2005)).lineplot(
#     hue="scenario", style="model", ax=ax, time_axis="year", palette=RCMIP_SCENARIO_COLOURS,
#     hue_order=RCMIP_SCENARIO_COLOURS.keys(),
# )
x.filter(variable="Surface Temperature").relative_to_ref_period_mean(year=range(1850,1900)).lineplot(
    hue="scenario",
    ax=ax,
    time_axis="year",
    palette=RCMIP_SCENARIO_COLOURS,
    hue_order=RCMIP_SCENARIO_COLOURS.keys(),
)
ax.set_xlim(1850,2100)
#ax.axhline(0, color='k', ls=':')
ax.grid()
ax.set_title('SSP projections with FaIR: 1850-2100')
plt.tight_layout()

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|BC").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|OC").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|Sulfur").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|Nitrate").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Indirect Effect").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|CO2").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|CH4").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|N2O").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Heat Uptake").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Airborne Fraction").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
x.filter(scenario='ssp119', variable="Atmospheric Concentrations|CO2").timeseries()
# Out:
# time                                                                            1750-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.656336
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  276.901839
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  276.988802
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  273.945406
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  275.908771
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.167879
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.629793
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.365672
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.152302
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.473379
#
# time                                                                            1751-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.668178
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  276.915357
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.001323
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  273.957302
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  275.922131
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.180485
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.641752
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.376847
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.165340
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.484438
#
# time                                                                            1752-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.692254
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  276.942088
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.026416
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  273.981467
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  275.948569
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.205745
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.665996
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.399968
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.191262
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.507369
#
# time                                                                            1753-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.716575
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  276.968267
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.051377
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.005851
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  275.974482
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.230873
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.690410
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.423721
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.216820
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.530966
#
# time                                                                            1754-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.740513
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  276.993992
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.075941
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.029839
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  275.999949
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.255612
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.714437
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.447064
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.241960
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.554133
#
# time                                                                            1755-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.764000
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.019339
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.100096
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.053362
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  276.025042
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.279943
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.738016
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.469892
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.266717
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.576774
#
# time                                                                            1756-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.787094
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.044367
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.123900
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.076477
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  276.049827
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.303917
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.761206
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.492274
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.291148
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.598974
#
# time                                                                            1757-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.809906
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.069126
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.147461
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.099280
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  276.074390
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.327596
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.784122
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.514316
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.315332
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.620852
#
# time                                                                            1758-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.832500
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.093642
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.170843
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.121841
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  276.098775
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.351021
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.806837
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.536093
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.339315
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.642494
#
# time                                                                            1759-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.854933
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.118034
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  277.194075
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  274.144259
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  276.123030
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  278.374294
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  276.829392
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  276.557708
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  276.363160
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  274.663989
#
# time                                                                            ...  \
# climate_model model region run_id scenario unit variable                        ...
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  ...
# ...                                                                             ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  ...
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  ...
#
# time                                                                            2091-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  398.242291
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  392.205849
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  395.283471
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  397.906387
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  394.618688
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  394.244170
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  397.412389
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  398.620481
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  393.150363
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  401.430678
#
# time                                                                            2092-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  397.083385
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  391.122427
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  394.173476
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  396.734200
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  393.506197
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  393.153187
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  396.273952
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  397.458288
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  392.052246
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  400.226772
#
# time                                                                            2093-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  395.907146
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  390.023578
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  393.047001
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  395.544372
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  392.377121
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  392.046240
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  395.118353
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  396.278952
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  390.938449
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  399.003853
#
# time                                                                            2094-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  394.713659
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  388.909394
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  391.904104
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  394.337033
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  391.231491
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  390.923408
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  393.945672
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  395.082584
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  389.809028
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  397.762043
#
# time                                                                            2095-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  393.503090
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  387.780291
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  390.744900
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  393.112472
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  390.069479
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  389.784976
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  392.756061
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  393.869523
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  388.664213
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  396.501573
#
# time                                                                            2096-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  392.275669
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  386.636773
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  389.569556
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  391.871034
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  388.891329
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  388.631312
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  391.549735
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  392.640223
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  387.504312
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  395.222731
#
# time                                                                            2097-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  391.031551
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  385.479095
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  388.378164
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  390.612923
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  387.697179
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  387.462624
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  390.326832
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  391.394993
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  386.329498
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  393.925712
#
# time                                                                            2098-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  389.770817
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  384.307278
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  387.170754
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  389.338208
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  386.487053
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  386.278956
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  389.087417
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  390.133980
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  385.139813
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  392.610618
#
# time                                                                            2099-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  388.493589
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  383.121237
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  385.947412
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  388.046951
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  385.260987
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  385.080318
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  387.831600
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  388.857282
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  383.935282
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  391.277580
#
# time                                                                            2100-01-01
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  387.200026
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  381.920814
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  384.708272
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  386.739225
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  384.019021
# ...                                                                                    ...
#                            2044   ssp119   ppm  Atmospheric Concentrations|CO2  383.866694
#                            2045   ssp119   ppm  Atmospheric Concentrations|CO2  386.559531
#                            2046   ssp119   ppm  Atmospheric Concentrations|CO2  387.564949
#                            2047   ssp119   ppm  Atmospheric Concentrations|CO2  382.715922
#                            2048   ssp119   ppm  Atmospheric Concentrations|CO2  389.926760
#
# [2049 rows x 351 columns]

# %%
x.filter(variable="Atmospheric Concentrations|N2O", scenario='ssp119', run_id=0).timeseries().values.squeeze()[264]
# Out:
# 326.97706689529565

# %%
x.filter(variable="Atmospheric Concentrations|CH4", scenario='ssp119', run_id=0).timeseries().values.squeeze()[264]
# Out:
# 1831.4709981235555
