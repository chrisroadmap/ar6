# %% [markdown]
# # Apply the constrained setup and run in openscm-runner
#
# - Working Group 3 style setup
# - TODO: parallel

# %%
import os.path

import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyam
from fair.forward import fair_scm
from scmdata import ScmRun, run_append
from tqdm import tqdm_notebook

import openscm_runner
from openscm_runner.run import run
from openscm_runner.adapters import FAIR
# Out:
# /nfs/b0110/Users/mencsm/miniconda3/envs/ar6/lib/python3.7/site-packages/openscm_runner/run.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
openscm_runner.__version__
# Out:
# '0.4.4'

# %%
fair = FAIR()
fair.get_version()
# Out:
# '1.6.2'

# %%
with open('../data_output_large/fair-samples/fair-1.6.2-wg3-params.json') as f:
    config_list = json.load(f)

# %%
# what a pain

species = [
'Emissions|BC',
'Emissions|CH4',
'Emissions|CO',
'Emissions|CO2|MAGICC AFOLU',
'Emissions|CO2|MAGICC Fossil and Industrial',
'Emissions|F-Gases|HFC|HFC125',
'Emissions|F-Gases|HFC|HFC134a',
'Emissions|F-Gases|HFC|HFC143a',
'Emissions|F-Gases|HFC|HFC227ea',
'Emissions|F-Gases|HFC|HFC23',
'Emissions|F-Gases|HFC|HFC245fa',
'Emissions|F-Gases|HFC|HFC32',
'Emissions|F-Gases|HFC|HFC4310mee',
'Emissions|F-Gases|PFC|C2F6',
'Emissions|F-Gases|PFC|C6F14',
'Emissions|F-Gases|PFC|CF4',
'Emissions|F-Gases|SF6',
'Emissions|Montreal Gases|CCl4',
'Emissions|Montreal Gases|CFC|CFC11',
'Emissions|Montreal Gases|CFC|CFC113',
'Emissions|Montreal Gases|CFC|CFC114',
'Emissions|Montreal Gases|CFC|CFC115',
'Emissions|Montreal Gases|CFC|CFC12',
'Emissions|Montreal Gases|CH3Br',
'Emissions|Montreal Gases|CH3CCl3',
'Emissions|Montreal Gases|CH3Cl',
'Emissions|Montreal Gases|HCFC141b',
'Emissions|Montreal Gases|HCFC142b',
'Emissions|Montreal Gases|HCFC22',
'Emissions|Montreal Gases|Halon1202',
'Emissions|Montreal Gases|Halon1211',
'Emissions|Montreal Gases|Halon1301',
'Emissions|Montreal Gases|Halon2402',
'Emissions|N2O',
'Emissions|NH3',
'Emissions|NOx',
'Emissions|OC',
'Emissions|Sulfur',
'Emissions|VOC']

# %%
df_fair = ScmRun('../data_input_large/rcmip-emissions-annual-means-v5-1-0.csv', lowercase_cols=True)
df_fair.filter(
    scenario=['ssp119','ssp126','ssp245','ssp370','ssp434','ssp460','ssp534-over','ssp585'], 
#    year=range(2015,2301),
    year=range(2015,2101),
    variable=species,
    region='World', 
    inplace=True
)
print(len(df_fair))
#df_fair.head(50)
# Out:
# 312

# %%
nt = df_fair.time_points.years()[-1] - 1750 + 1
nt
# Out:
# 351

# %%
# # add in natural emissions and natural forcing
# ch4_n2o_df = pd.read_csv('../data/cmip6_natural_ch4_n2o.csv')
# ch4_n2o = ch4_n2o_df.values[:nt,1:]
# sol_vol_df = pd.read_csv('../data/cmip6_natural_forcing.csv')
# solar_forcing = sol_vol_df.values[:nt,1]
# volcanic_forcing = sol_vol_df.values[:nt,2]

# %%
#config_list[0]

# %%
# convert lists to numpy arrays
updated_config = []
for i in range(len(config_list)):
    updated_config.append({})
    for key, value in config_list[i].items():
        if type(value)==list:
            updated_config[i][key] = np.asarray(value)
        else:
            updated_config[i][key] = value
#     updated_config[i]['endyear'] = 2300
#     updated_config[i]['natural'] = ch4_n2o
#     updated_config[i]['F_solar'] = solar_forcing
#     updated_config[i]['F_volcanic'] = volcanic_forcing

# %%
# need parallel FaIR in openscm-runner

x = run(
    climate_models_cfgs={
        "FAIR": updated_config,
    },
    scenarios=df_fair,
    output_variables=(
        "Surface Temperature",
        "Surface Temperature (GMST)",
        "Atmospheric Concentrations|CO2",
        "Atmospheric Concentrations|CH4",
        "Atmospheric Concentrations|N2O",
        "Effective Radiative Forcing",
        "Effective Radiative Forcing|CO2",
        "Effective Radiative Forcing|CH4",
        "Effective Radiative Forcing|N2O",
        "Effective Radiative Forcing|Greenhouse Gases",
        "Effective Radiative Forcing|Aerosols",
        "Effective Radiative Forcing|Aerosols|Direct Effect|BC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|OC",
        "Effective Radiative Forcing|Aerosols|Direct Effect|Sulfur",
        "Effective Radiative Forcing|Aerosols|Direct Effect|Nitrate",
        "Effective Radiative Forcing|Aerosols|Direct Effect",
        "Effective Radiative Forcing|Aerosols|Indirect Effect",
        "Heat Uptake",
        "Heat Uptake|Ocean",
        "Airborne Fraction",
    ),
)
# Out:
# Climate models:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating FaIR emissions inputs:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# convert to ScmRun for better plotting functionality
x = ScmRun(x.timeseries())

# %%
x.tail()
# Out:
# time                                                                                                                   1750-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  4.927383e-10
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  5.073510e-10
#                                                    J/yr          Heat Uptake                                         4.848681e+21
#                                                                  Heat Uptake|Ocean                                   4.460787e+21
#                                                    dimensionless Airborne Fraction                                   0.000000e+00
#
# time                                                                                                                   1751-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -5.399174e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  3.208472e-03
#                                                    J/yr          Heat Uptake                                         3.904076e+21
#                                                                  Heat Uptake|Ocean                                   3.591750e+21
#                                                    dimensionless Airborne Fraction                                   7.719283e-01
#
# time                                                                                                                   1752-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -4.974222e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  5.026909e-03
#                                                    J/yr          Heat Uptake                                         2.843310e+21
#                                                                  Heat Uptake|Ocean                                   2.615845e+21
#                                                    dimensionless Airborne Fraction                                   7.073832e-01
#
# time                                                                                                                   1753-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -6.316151e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  3.275924e-03
#                                                    J/yr          Heat Uptake                                         1.976943e+21
#                                                                  Heat Uptake|Ocean                                   1.818787e+21
#                                                    dimensionless Airborne Fraction                                   6.707135e-01
#
# time                                                                                                                   1754-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -4.907423e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.310244e-03
#                                                    J/yr          Heat Uptake                                         1.235047e+21
#                                                                  Heat Uptake|Ocean                                   1.136243e+21
#                                                    dimensionless Airborne Fraction                                   6.439494e-01
#
# time                                                                                                                   1755-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  3.247379e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  9.413713e-04
#                                                    J/yr          Heat Uptake                                         4.985618e+20
#                                                                  Heat Uptake|Ocean                                   4.586769e+20
#                                                    dimensionless Airborne Fraction                                   6.224579e-01
#
# time                                                                                                                   1756-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -9.768937e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  3.128312e-03
#                                                    J/yr          Heat Uptake                                        -2.114871e+21
#                                                                  Heat Uptake|Ocean                                  -1.945682e+21
#                                                    dimensionless Airborne Fraction                                   6.042147e-01
#
# time                                                                                                                   1757-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  1.918082e-03
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -3.598538e-03
#                                                    J/yr          Heat Uptake                                        -2.502513e+21
#                                                                  Heat Uptake|Ocean                                  -2.302312e+21
#                                                    dimensionless Airborne Fraction                                   5.885493e-01
#
# time                                                                                                                   1758-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  9.652032e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.140068e-03
#                                                    J/yr          Heat Uptake                                         3.784981e+20
#                                                                  Heat Uptake|Ocean                                   3.482183e+20
#                                                    dimensionless Airborne Fraction                                   5.746896e-01
#
# time                                                                                                                   1759-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  5.049597e-04
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.716819e-03
#                                                    J/yr          Heat Uptake                                         2.106334e+21
#                                                                  Heat Uptake|Ocean                                   1.937828e+21
#                                                    dimensionless Airborne Fraction                                   5.625242e-01
#
# time                                                                                                                 ...  \
# climate_model model         region run_id scenario unit          variable                                            ...
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect  ...
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E...  ...
#                                                    J/yr          Heat Uptake                                         ...
#                                                                  Heat Uptake|Ocean                                   ...
#                                                    dimensionless Airborne Fraction                                   ...
#
# time                                                                                                                   2091-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.702792e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.875766e-01
#                                                    J/yr          Heat Uptake                                         2.889193e+22
#                                                                  Heat Uptake|Ocean                                   2.658058e+22
#                                                    dimensionless Airborne Fraction                                   6.051992e-01
#
# time                                                                                                                   2092-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.712040e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.822056e-01
#                                                    J/yr          Heat Uptake                                         2.921378e+22
#                                                                  Heat Uptake|Ocean                                   2.687668e+22
#                                                    dimensionless Airborne Fraction                                   6.073774e-01
#
# time                                                                                                                   2093-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.721313e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.767730e-01
#                                                    J/yr          Heat Uptake                                         2.926508e+22
#                                                                  Heat Uptake|Ocean                                   2.692387e+22
#                                                    dimensionless Airborne Fraction                                   6.095038e-01
#
# time                                                                                                                   2094-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.730561e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.713079e-01
#                                                    J/yr          Heat Uptake                                         2.896598e+22
#                                                                  Heat Uptake|Ocean                                   2.664870e+22
#                                                    dimensionless Airborne Fraction                                   6.115811e-01
#
# time                                                                                                                   2095-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.739808e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.657945e-01
#                                                    J/yr          Heat Uptake                                         2.866409e+22
#                                                                  Heat Uptake|Ocean                                   2.637096e+22
#                                                    dimensionless Airborne Fraction                                   6.136105e-01
#
# time                                                                                                                   2096-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.749056e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.602319e-01
#                                                    J/yr          Heat Uptake                                         2.841383e+22
#                                                                  Heat Uptake|Ocean                                   2.614073e+22
#                                                    dimensionless Airborne Fraction                                   6.155929e-01
#
# time                                                                                                                   2097-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.758329e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.546040e-01
#                                                    J/yr          Heat Uptake                                         2.827535e+22
#                                                                  Heat Uptake|Ocean                                   2.601332e+22
#                                                    dimensionless Airborne Fraction                                   6.175298e-01
#
# time                                                                                                                   2098-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.767577e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.489404e-01
#                                                    J/yr          Heat Uptake                                         2.825251e+22
#                                                                  Heat Uptake|Ocean                                   2.599231e+22
#                                                    dimensionless Airborne Fraction                                   6.194226e-01
#
# time                                                                                                                   2099-01-01  \
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.776825e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.432249e-01
#                                                    J/yr          Heat Uptake                                         2.835191e+22
#                                                                  Heat Uptake|Ocean                                   2.608375e+22
#                                                    dimensionless Airborne Fraction                                   6.212739e-01
#
# time                                                                                                                   2100-01-01
# climate_model model         region run_id scenario unit          variable
# FaIRv1.6.2    REMIND-MAGPIE World  17895  ssp585   W/m**2        Effective Radiative Forcing|Aerosols|Direct Effect -1.786073e-01
#                                                                  Effective Radiative Forcing|Aerosols|Indirect E... -1.374567e-01
#                                                    J/yr          Heat Uptake                                         2.864037e+22
#                                                                  Heat Uptake|Ocean                                   2.634914e+22
#                                                    dimensionless Airborne Fraction                                   6.230863e-01
#
# [5 rows x 351 columns]

# %%
def new_timeseries(
    n=100,
    count=1,
    model="example",
    scenario="ssp119",
    variable="Surface Temperature",
    unit="K",
    region="World",
    cls=ScmRun,
    **kwargs,
):
    data = np.random.rand(n, count) * np.arange(n)[:, np.newaxis]
    index = 2000 + np.arange(n)
    return cls(
        data,
        columns={
            "model": model,
            "scenario": scenario,
            "variable": variable,
            "region": region,
            "unit": unit,
            **kwargs,
        },
        index=index,
    )

# %%
# save output to netCDF
x.to_nc('../data_output_large/fair-samples/ssp_emissions_driven_runs.nc', dimensions=["run_id", "scenario", "model"])

# %%
x = ScmRun.from_nc('../data_output_large/fair-samples/ssp_emissions_driven_runs.nc')

from scmdata.plotting import RCMIP_SCENARIO_COLOURS

# %%
plt.rcParams['font.size'] = 14
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
# x.filter(variable="Surface Temperature").relative_to_ref_period_mean(year=range(1985,2005)).lineplot(
#     hue="scenario", style="model", ax=ax, time_axis="year", palette=RCMIP_SCENARIO_COLOURS,
#     hue_order=RCMIP_SCENARIO_COLOURS.keys(),
# )
x.filter(variable="Surface Temperature").relative_to_ref_period_mean(year=range(1850,1900)).lineplot(
    hue="scenario",
    ax=ax,
    time_axis="year",
    palette=RCMIP_SCENARIO_COLOURS,
    hue_order=RCMIP_SCENARIO_COLOURS.keys(),
)
ax.set_xlim(1850,2100)
#ax.axhline(0, color='k', ls=':')
ax.grid()
ax.set_title('SSP projections with FaIR: 1850-2100')
plt.tight_layout()

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|BC").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|OC").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|Sulfur").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect|Nitrate").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Direct Effect").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Effective Radiative Forcing|Aerosols|Indirect Effect").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|CO2").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|CH4").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Atmospheric Concentrations|N2O").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Heat Uptake").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
ax = plt.figure(figsize=(12, 7)).add_subplot(111)
x.filter(variable="Airborne Fraction").lineplot(
    hue="scenario", style="model", ax=ax, time_axis="year"
)

# %%
x.filter(scenario='ssp119', variable="Atmospheric Concentrations|CO2").timeseries()
# Out:
# time                                                                            1750-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.656336
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  276.988802
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  273.945406
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  275.908771
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  277.697773
# ...                                                                                    ...
#                            2232   ssp119   ppm  Atmospheric Concentrations|CO2  278.167879
#                            2233   ssp119   ppm  Atmospheric Concentrations|CO2  276.629793
#                            2234   ssp119   ppm  Atmospheric Concentrations|CO2  276.365672
#                            2235   ssp119   ppm  Atmospheric Concentrations|CO2  276.152302
#                            2236   ssp119   ppm  Atmospheric Concentrations|CO2  279.328208
#
# time                                                                            1751-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.668178
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.001323
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  273.957302
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  275.922131
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  277.710056
# ...                                                                                    ...
#                            2232   ssp119   ppm  Atmospheric Concentrations|CO2  278.180485
#                            2233   ssp119   ppm  Atmospheric Concentrations|CO2  276.641752
#                            2234   ssp119   ppm  Atmospheric Concentrations|CO2  276.376847
#                            2235   ssp119   ppm  Atmospheric Concentrations|CO2  276.165340
#                            2236   ssp119   ppm  Atmospheric Concentrations|CO2  279.339172
#
# time                                                                            1752-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.692254
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.026416
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  273.981467
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  275.948568
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  277.734830
# ...                                                                                    ...
#                            2232   ssp119   ppm  Atmospheric Concentrations|CO2  278.205744
#                            2233   ssp119   ppm  Atmospheric Concentrations|CO2  276.665995
#                            2234   ssp119   ppm  Atmospheric Concentrations|CO2  276.399968
#                            2235   ssp119   ppm  Atmospheric Concentrations|CO2  276.191261
#                            2236   ssp119   ppm  Atmospheric Concentrations|CO2  279.361986
#
# time                                                                            1753-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.716574
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.051376
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  274.005848
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  275.974480
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  277.759657
# ...                                                                                    ...
#                            2232   ssp119   ppm  Atmospheric Concentrations|CO2  278.230869
#                            2233   ssp119   ppm  Atmospheric Concentrations|CO2  276.690410
#                            2234   ssp119   ppm  Atmospheric Concentrations|CO2  276.423717
#                            2235   ssp119   ppm  Atmospheric Concentrations|CO2  276.216818
#                            2236   ssp119   ppm  Atmospheric Concentrations|CO2  279.385539
#
# time                                                                            1754-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.740510
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.075940
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  274.029832
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  275.999943
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  277.784112
# ...                                                                                    ...
#                            2232   ssp119   ppm  Atmospheric Concentrations|CO2  278.255603
#                            2233   ssp119   ppm  Atmospheric Concentrations|CO2  276.714436
#                            2234   ssp119   ppm  Atmospheric Concentrations|CO2  276.447054
#                            2235   ssp119   ppm  Atmospheric Concentrations|CO2  276.241955
#                            2236   ssp119   ppm  Atmospheric Concentrations|CO2  279.408672
#
# time                                                                            1755-01-01  \
# climate_model model region run_id scenario unit variable
# FaIRv1.6.2    IMAGE World  0      ssp119   ppm  Atmospheric Concentrations|CO2  275.763994
#                            1      ssp119   ppm  Atmospheric Concentrations|CO2  277.100095
#                            2      ssp119   ppm  Atmospheric Concentrations|CO2  274.053349
#                            3      ssp119   ppm  Atmospheric Concentrations|CO2  276.025031
#                            4      ssp119   ppm  Atmospheric Concentrations|CO2  277.808138
# ...                                                                                    ...
#                            2232   ssp119   ppm  Atmospheric Concentrations|CO2  278.279927
#                            2233   ssp119   ppm  Atmospheric Concentrations|CO2  276