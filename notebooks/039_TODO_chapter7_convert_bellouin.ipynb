# %% [markdown]
# # Convert Nicolas Bellouin's raw data
#
# Input file is not publicly available, so might move to 004

# %%
import numpy as np
from scipy.interpolate import interp1d
import pandas as pd

import matplotlib.pyplot as pl
# %matplotlib inline
